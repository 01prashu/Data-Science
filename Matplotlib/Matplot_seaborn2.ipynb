# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
italydf=pd.read_csv('italy-covid-daywise.csv')

# %%
italydf
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
plt.plot(italydf.new_cases , italydf.new_deaths);
plt.title("Line Plot")
plt.xlabel("New Cases")
plt.ylabel("New Deaths")

#legend uses when we are dealing with two graph at a time but in this example we are working with sinle graph
plt.legend(['New Cases' , 'New Deaths'])

# %%
import seaborn as sns

# %%
sns.scatterplot(x = italydf.new_cases , y = italydf.new_deaths)
# Out:
# <Axes: xlabel='new_cases', ylabel='new_deaths'>

# %%
# if we want to add grid then use set_style("darkgrid")
sns.set_style('darkgrid')

# %%
plt.title("Scatter Graph")
sns.scatterplot(x = italydf.new_cases , y = italydf.new_deaths);

# %%
italydf
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
#create month column 
it=pd.DatetimeIndex(italydf.date)

# %%
italydf=pd.read_csv('italy-covid-daywise.csv')

# %%
italydf
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
italydf.date
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
italydf.date=pd.DatetimeIndex(italydf.date)

# %%
italydf.date
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
italydf['Months']=pd.DatetimeIndex(italydf.date).month
italydf
# Out:
#           date  new_cases  new_deaths  new_tests  Months
# 0   2019-12-31        0.0         0.0        NaN      12
# 1   2020-01-01        0.0         0.0        NaN       1
# 2   2020-01-02        0.0         0.0        NaN       1
# 3   2020-01-03        0.0         0.0        NaN       1
# 4   2020-01-04        0.0         0.0        NaN       1
# ..         ...        ...         ...        ...     ...
# 243 2020-08-30     1444.0         1.0    53541.0       8
# 244 2020-08-31     1365.0         4.0    42583.0       8
# 245 2020-09-01      996.0         6.0    54395.0       9
# 246 2020-09-02      975.0         8.0        NaN       9
# 247 2020-09-03     1326.0         6.0        NaN       9
#
# [248 rows x 5 columns]

# %%
# now we can find graph of newcases vs new deaths at diffrent month

# %%
plt.figure(figsize=(22 , 15))
sns.scatterplot(x = italydf.new_cases , y = italydf.new_deaths ,
               hue = italydf.Months , s=100 )
# Out:
# <Axes: xlabel='new_cases', ylabel='new_deaths'>

# %% [markdown]
# # Histrograms

# %%
italydf.describe()
# Out:
#                       date    new_cases  new_deaths     new_tests      Months
# count                  248   248.000000  248.000000    135.000000  248.000000
# mean   2020-05-02 12:00:00  1094.818548  143.133065  31699.674074    4.600806
# min    2019-12-31 00:00:00  -148.000000  -31.000000   7841.000000    1.000000
# 25%    2020-03-01 18:00:00   123.000000    3.000000  25259.000000    3.000000
# 50%    2020-05-02 12:00:00   342.000000   17.000000  29545.000000    5.000000
# 75%    2020-07-03 06:00:00  1371.750000  175.250000  37711.000000    7.000000
# max    2020-09-03 00:00:00  6557.000000  971.000000  95273.000000   12.000000
# std                    NaN  1554.508002  227.105538  11622.209757    2.382018

# %%
plt.title("Drawing Histrogram")
plt.hist(italydf.new_cases)
# Out:
# (array([145.,  34.,  17.,   9.,  11.,   8.,   8.,   7.,   4.,   5.]),
#  array([-148. ,  522.5, 1193. , 1863.5, 2534. , 3204.5, 3875. , 4545.5,
#         5216. , 5886.5, 6557. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(20 , 8))
plt.hist(italydf.new_cases , bins=5)
# Out:
# (array([179.,  26.,  19.,  15.,   9.]),
#  array([-148., 1193., 2534., 3875., 5216., 6557.]),
#  <BarContainer object of 5 artists>)

# %%
plt.title("Histrogram")
plt.figure(figsize=(25 , 6))
plt.hist(italydf.new_cases , bins=np.arange(0 ,2500 ,500));

# %%
greaterdata=italydf.new_cases > 3000
greaterdata
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# Name: new_cases, Length: 248, dtype: bool

# %%
italydf[greaterdata]
# Out:
#           date  new_cases  new_deaths  new_tests  Months
# 75  2020-03-15     3497.0       173.0        NaN       3
# 77  2020-03-17     4000.0       347.0        NaN       3
# 78  2020-03-18     3526.0       347.0        NaN       3
# 79  2020-03-19     4207.0       473.0        NaN       3
# 80  2020-03-20     5322.0       429.0        NaN       3
# 81  2020-03-21     5986.0       625.0        NaN       3
# 82  2020-03-22     6557.0       795.0        NaN       3
# 83  2020-03-23     5560.0       649.0        NaN       3
# 84  2020-03-24     4789.0       601.0        NaN       3
# 85  2020-03-25     5249.0       743.0        NaN       3
# 86  2020-03-26     5210.0       685.0        NaN       3
# 87  2020-03-27     6153.0       660.0        NaN       3
# 88  2020-03-28     5959.0       971.0        NaN       3
# 89  2020-03-29     5974.0       887.0        NaN       3
# 90  2020-03-30     5217.0       758.0        NaN       3
# ...

# %%
plt.title("Histrogram")
plt.figure(figsize=(25 , 6))
plt.hist(italydf.new_cases , bins=np.arange(0 ,7000 ,500));

# %%
firstmonth=italydf[italydf.Months == 8]
secondmonth=italydf[italydf.Months == 3]
thirdmonth = italydf[italydf.Months == 4]
firstmonth
# Out:
#           date  new_cases  new_deaths  new_tests  Months
# 214 2020-08-01      379.0         9.0    31905.0       8
# 215 2020-08-02      295.0         5.0    24496.0       8
# 216 2020-08-03      238.0         8.0    13467.0       8
# 217 2020-08-04      159.0        12.0    23491.0       8
# 218 2020-08-05      190.0         5.0    29739.0       8
# 219 2020-08-06      384.0        10.0    32169.0       8
# 220 2020-08-07      401.0         6.0    30392.0       8
# 221 2020-08-08      552.0         3.0    26631.0       8
# 222 2020-08-09      347.0        13.0    22773.0       8
# 223 2020-08-10      463.0         2.0    10904.0       8
# 224 2020-08-11      259.0         4.0    22063.0       8
# 225 2020-08-12      412.0         6.0    27330.0       8
# 226 2020-08-13      476.0        10.0    25629.0       8
# 227 2020-08-14      522.0         6.0    24868.0       8
# 228 2020-08-15      574.0         3.0    25937.0       8
# ...

# %%
plt.hist(firstmonth.new_cases , alpha=0.6)
plt.hist(secondmonth.new_cases , alpha=0.4)
plt.hist(thirdmonth.new_cases , alpha= 0.4)
plt.legend(['8th Month' , '3rd month' ,'4th month'])

# %%
plt.hist([firstmonth.new_cases ,secondmonth.new_cases ,thirdmonth.new_cases] , stacked=True)
plt.legend(["8th Month" ,"3rd Month" , "4th month"])

# %% [markdown]
# # Bar chart
# Bar chart is similar to line chart but bar chat give more detailed information about the as compared to line chart..Bar chat are more easy to understand as compared to line chart

# %%
plt.bar(italydf.Months , italydf.new_cases )
plt.bar(italydf.Months , italydf.new_deaths , bottom=italydf.new_cases)
# Out:
# <BarContainer object of 248 artists>

# %% [markdown]
# # Barplot

# %%
orangedf=pd.DataFrame(np.arange(10 , 100 ))

# %%
orangedf
# Out:
#      0
# 0   10
# 1   11
# 2   12
# 3   13
# 4   14
# ..  ..
# 85  95
# 86  96
# 87  97
# 88  98
# 89  99
#
# [90 rows x 1 columns]

# %%
appledf=pd.DataFrame(np.arange(100 , 1000 , 10))
appledf
# Out:
#       0
# 0   100
# 1   110
# 2   120
# 3   130
# 4   140
# ..  ...
# 85  950
# 86  960
# 87  970
# 88  980
# 89  990
#
# [90 rows x 1 columns]

# %%
orangedf['Sex']="Male"
appledf['Sex']="Female"
orangedf
appledf
# Out:
#       0     Sex
# 0   100  Female
# 1   110  Female
# 2   120  Female
# 3   130  Female
# 4   140  Female
# ..  ...     ...
# 85  950  Female
# 86  960  Female
# 87  970  Female
# 88  980  Female
# 89  990  Female
#
# [90 rows x 2 columns]

# %%
plt.bar(orangedf.Sex , orangedf[0])
plt.bar(appledf.Sex , appledf[0])
# Out:
# <BarContainer object of 90 artists>

# %%
plt.barplot()
