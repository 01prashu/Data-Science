# %%
import pandas as pd

# %%
import urllib.request
urllib.request.urlretrieve('https://gist.githubusercontent.com/aakashns/28b2e504b3350afd9bdb157893f9725c/raw/994b65665757f4f8887db1c85986a897abb23d84/countries.csv', 
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x269ba041790>)

# %%
countriesdf=pd.read_csv('countries.csv')

# %%
countriesdf
# Out:
#            location continent  population  life_expectancy
# 0       Afghanistan      Asia  38928341.0            64.83  \
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
#Q) how many countries does the dataframe contain
numcountries = countriesdf.shape
print("There are " , numcountries)
# Out:
# There are  (210, 6)

# %%
#q) Retrieve list of continents from above list

numcontinents=countriesdf.continent.unique()
numcontinents

#unique function provide list of unique data from mention column
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
# Q) What is total population of all the listed datasets

# %%
totalpopulation=countriesdf.population.sum()
totalpopulation
# Out:
# 7757980095.0

# %%
#Q4: Create a dataframe containing 10 countries with the highest population.

# %%
sortedvalue=countriesdf.sort_values("population" ,ascending=False)

# %%
sortedvalue.head(10)
# Out:
#           location      continent    population  life_expectancy
# 41           China           Asia  1.439324e+09            76.91  \
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %%
#**Q: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.**

# %%
lowestgdp=countriesdf.sort_values("gdp_per_capita")
# lowestgdp=countriesdf.population > 10000000
# countriesdf[lowestgdp].head(10)
lowestgdp
ans=lowestgdp.population >100000000
ans
lowestgdp[ans].head(10)
# Out:
#         location      continent    population  life_expectancy
# 63      Ethiopia         Africa  1.149636e+08            66.60  \
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita
# 63                         0.30        1729.927
# 15                         0.80        3523.984
# 145                        0.60        5034.708
# 141                         NaN        5338.454
# ...

# %%
# Create a data frame that counts the number countries in each continent?

# %%
nocontinents=countriesdf.groupby('continent')
nocontinents.location.count()
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %%
populationcontinent=nocontinents.population.sum()
populationcontinent

# find population of each continent
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %% [markdown]
#  # work with another file

# %%
urllib.request.urlretrieve('https://gist.githubusercontent.com/aakashns/b2a968a6cfd9fbbb0ff3d6bd0f26262b/raw/b115ed1dfa17f10fc88bf966236cd4d9032f1df8/covid-countries-data.csv', 
            'covid-countries-data.csv')
# Out:
# ('covid-countries-data.csv', <http.client.HTTPMessage at 0x269b98851d0>)

# %%
# Q) Count the number of countries for which the total_tests data is missing.
covid_country_df=pd.read_csv('covid-countries-data.csv')
covid_country_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %%
c=covid_country_df.total_tests=="NaN"

# %%
# merge countries_df with covid_data_df on location column

# %%
mergedf=covid_country_df.merge(countriesdf)

# %%
mergedf
# Out:
#            location  total_cases  total_deaths  total_tests continent
# 0       Afghanistan      38243.0        1409.0          NaN      Asia  \
# 1           Albania       9728.0         296.0          NaN    Europe
# 2           Algeria      45158.0        1525.0          NaN    Africa
# 3           Andorra       1199.0          53.0          NaN    Europe
# 4            Angola       2729.0         109.0          NaN    Africa
# ..              ...          ...           ...          ...       ...
# 205         Vietnam       1046.0          35.0     261004.0      Asia
# 206  Western Sahara        766.0           1.0          NaN    Africa
# 207           Yemen       1976.0         571.0          NaN      Asia
# 208          Zambia      12415.0         292.0          NaN    Africa
# 209        Zimbabwe       6638.0         206.0      97272.0    Africa
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita
# ...

# %%
highest_cases=mergedf.sort_values('total_cases' , ascending=False)
storelocation = highest_cases.head(10)

# %%
d=storelocation.location
print(d)
# Out:
# 199    United States
# 27            Brazil
# 90             India
# 157           Russia
# 150             Peru
# 42          Colombia
# 174     South Africa
# 125           Mexico
# 177            Spain
# 7          Argentina
# Name: location, dtype: object
