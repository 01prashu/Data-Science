# %%
import opendatasets as od
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import opendatasets as od
#
# ModuleNotFoundError: No module named 'opendatasets'

# %%
pip install opendatasets
# Out:
# ...
#                                               0.0/78.3 kB ? eta -:--:--
#      ---------------                          30.7/78.3 kB 1.3 MB/s eta 0:00:01
#      ----------------------------------     71.7/78.3 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 78.3/78.3 kB 624.0 kB/s eta 0:00:00
# ...
#                                               0.0/83.6 kB ? eta -:--:--
#      -----------------------------            61.4/83.6 kB 3.2 MB/s eta 0:00:01
#      ---------------------------------------- 83.6/83.6 kB 1.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#                                               0.0/97.9 kB ? eta -:--:--
# ...

# %%
import opendatasets as od

# %%
dataseturl="https://www.kaggle.com/datasets/anmolkumar/health-insurance-cross-sell-prediction"

# %%
# od.download(dataseturl)

# %%
import os
os.listdir('./')
# Out:
# ['.ipynb_checkpoints',
#  'Health Insurance Cross sell .ipynb',
#  'sample_submission.csv',
#  'test.csv',
#  'train.csv']

# %%
os.listdir('./Health Insurance Files')
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %% [markdown]
# # Data Prepration and cleaning

# %%
import pandas as pd
traindf=pd.read_csv('Health Insurance Files/train.csv')

# %%
traindf
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured
# 0            1    Male   44                1         28.0                   0  \
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
lno=traindf.Driving_License==1
lno
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 381104    True
# 381105    True
# 381106    True
# 381107    True
# 381108    True
# Name: Driving_License, Length: 381109, dtype: bool

# %%
traindf[lno]
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured
# 0            1    Male   44                1         28.0                   0  \
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
# if customer have already vehicle insurance then they dont't go for again so remove those insurance...
alreadyinsurance = traindf.Previously_Insured==0
alreadyinsurance
traindf[alreadyinsurance]
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured
# 0            1    Male   44                1         28.0                   0  \
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 5            6  Female   24                1         33.0                   0
# 6            7    Male   23                1         11.0                   0
# ...        ...     ...  ...              ...          ...                 ...
# 381100  381101  Female   29                1         28.0                   0
# 381101  381102  Female   70                1         28.0                   0
# 381103  381104    Male   47                1         50.0                   0
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
traindf.describe()
# Out:
#                   id            Age  Driving_License    Region_Code
# count  381109.000000  381109.000000    381109.000000  381109.000000  \
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel
# count       381109.000000   381109.000000         381109.000000  \
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...
